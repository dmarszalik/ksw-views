# %%
import pandas as pd
import re

from nltk.tokenize import RegexpTokenizer

from youtube_data_api import get_videos_with_keyword, get_video_statistics, get_channel_statistics

# %%
MAX_RESULTS_PER_PAGE = 50
TOTAL_VIDEOS = 200
DELAY_BETWEEN_REQUESTS = 1  # delay in seconds

# %%
videos = get_videos_with_keyword('KSW', TOTAL_VIDEOS, MAX_RESULTS_PER_PAGE, DELAY_BETWEEN_REQUESTS)

# %%
video_data = []
for video in videos:
    video_id = video['id']['videoId']
    title = video['snippet']['title']
    statistics = get_video_statistics(video_id)
    view_count = statistics.get('viewCount', 0)
    channel_id = video['snippet']['channelId']
    channel = video['snippet']['channelTitle']
    channel_statistics = get_channel_statistics(channel_id)
    channel_subscribers = channel_statistics.get('subscriberCount', 0)
    video_info = {
        'video_id': video_id,
        'title': title,
        'view_count': view_count,
        'channel': channel,
        'channel_subscribers': channel_subscribers
    }
    video_data.append(video_info)

# Confersion of dicts to DataFrame
df = pd.DataFrame(video_data)

# %%
df.head(10)
# Out:
#       video_id                                              title view_count  \
# 0  jAPParfHrxE  KSW 85: Salahdine Parnasse vs Robert Ruchała |...       9255
# 1  vDICqILiGQQ  HISTORYCZNA SPORTOWA WALKA NA FAME MMA?(KSW,UF...       4371
# 2  T1Emy34rGIk  Najlepsze nokauty i poddania bohaterów XTB KSW...     256569
# 3  nTj04YcA37k  Najlepsze nokauty i walka gali XTB KSW Colosse...     165422
# 4  zbvfrGob5mY  Kizo ft. Kabe, ReTo, Gruby Mielzky, Borixon - ...    6935619
# 5  9ApiSJm0nQo      KSW 84: TOP 10 Moments - Najlepsze akcje gali      17273
# 6  av889OfoiQE  Najlepsze momenty gali XTB KSW Colosseum 2 | X...      84654
# 7  cEy5oHrnCoQ  KSW 84: Bonusy - Najlepsze nokauty i poddania ...      13688
# 8  AMrL_AcVf04  OLIWIER JARZECKI | 2 WYGRANE NA JEDNEJ GALI | ...        236
# 9  -oG1dAzfq3I  Dzień z Adamem Soldaevem - Droga do XTB KSW Co...     138014
#
#                             channel channel_subscribers
# 0                               KSW              506000
# 1                          MMA INFO               11600
# 2                               KSW              506000
# 3                               KSW              506000
# 4                      MY TO SUKCES             1000000
# 5                               KSW              506000
# 6                               KSW              506000
# 7                               KSW              506000
# 8  Tv F-O-T-O  wydarzenia i wywiady                2250
# 9                               KSW              506000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   video_id             200 non-null    object
#  1   title                200 non-null    object
#  2   view_count           200 non-null    object
#  3   channel              200 non-null    object
#  4   channel_subscribers  200 non-null    object
# dtypes: object(5)
# memory usage: 7.9+ KB

# %% [markdown]
# I need to get rid of videos from official KSW channels as they are not my target and make disturbs in data

# %%
df_filtered = df[df['channel'] != 'KSW']

# %%
df_filtered
# Out:
#         video_id                                              title  \
# 1    vDICqILiGQQ  HISTORYCZNA SPORTOWA WALKA NA FAME MMA?(KSW,UF...
# 4    zbvfrGob5mY  Kizo ft. Kabe, ReTo, Gruby Mielzky, Borixon - ...
# 8    AMrL_AcVf04  OLIWIER JARZECKI | 2 WYGRANE NA JEDNEJ GALI | ...
# 10   e1-u_eF0UBA  KSW Free Fight: Mamed Khalidov vs. Mariusz Pud...
# 15   HDQDYa5jnWE  OGROMNE PROBLEMY KSW! CO DALEJ Z GALAMI? (VIAP...
# ..           ...                                                ...
# 189  73HjFUU4ZgM  KSW 84 - KREW, POT I ŁZY. NAROŻNIKI I BACKSTAG...
# 190  SFopg1oGO-A                      Fadipe vs Kaszubowski #ksw 84
# 192  6R0gjEtKNNc  SZPILKA ODGRYZA SIĘ PUDZIANOWSKIEMU po wygrane...
# 195  WFuJ2oz7TkM                                        Kizo w KSW…
# 196  h1InFyko9ns  Wrze po transferze do KSW. Maciej Kawulski odp...
#
#     view_count                           channel channel_subscribers
# 1         4371                          MMA INFO               11600
# 4      6935619                      MY TO SUKCES             1000000
# 8          236  Tv F-O-T-O  wydarzenia i wywiady                2250
# 10      144250                 KSW International               16700
# 15       10558                          MMA INFO               11600
# ..         ...                               ...                 ...
# 189      10297                    Kanał Sportowy             1070000
# 190        233                            afanik                 613
# 192     214322                          KOLOSEUM               66700
# 195      75380                      MY TO SUKCES             1000000
# 196      38350                  KLATKA po KLATCE               11500
#
# [127 rows x 5 columns]

# %%
def standardize_text(df_filtered, text_field):
    df_filtered[text_field] = df_filtered[text_field].str.lower()
    df_filtered[text_field] = df_filtered[text_field].apply(lambda elem: re.sub(r"http\S+", "", elem))  # get rid of URLs
    return df_filtered

clean_df = standardize_text(df_filtered, "title")
# Out:
# /var/folders/mp/mpgc14lx6b9f41xmhqs4mxc80000gn/T/ipykernel_15007/216360157.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[text_field] = df_filtered[text_field].str.lower()
# /var/folders/mp/mpgc14lx6b9f41xmhqs4mxc80000gn/T/ipykernel_15007/216360157.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[text_field] = df_filtered[text_field].apply(lambda elem: re.sub(r"http\S+", "", elem))  # get rid of URLs

# %%
clean_df.head()
# Out:
#        video_id                                              title view_count  \
# 1   vDICqILiGQQ  historyczna sportowa walka na fame mma?(ksw,uf...       4371
# 4   zbvfrGob5mY  kizo ft. kabe, reto, gruby mielzky, borixon - ...    6935619
# 8   AMrL_AcVf04  oliwier jarzecki | 2 wygrane na jednej gali | ...        236
# 10  e1-u_eF0UBA  ksw free fight: mamed khalidov vs. mariusz pud...     144250
# 15  HDQDYa5jnWE  ogromne problemy ksw! co dalej z galami? (viap...      10558
#
#                              channel channel_subscribers
# 1                           MMA INFO               11600
# 4                       MY TO SUKCES             1000000
# 8   Tv F-O-T-O  wydarzenia i wywiady                2250
# 10                 KSW International               16700
# 15                          MMA INFO               11600

# %%
clean_df.groupby("channel").count()
# Out:
#                                   video_id  title  view_count  \
# channel
# 6PAK                                     1      1           1
# BOXDEL                                   1      1           1
# FANSPORTU TV                            10     10          10
# Fair Play Thinker podcast                1      1           1
# FightsportPL                             3      3           3
# Fortuna - Zakłady bukmacherskie          2      2           2
# InTheCagePL                             15     15          15
# Interia Sport                            1      1           1
# KANAŁ O WALKACH                          1      1           1
# KLATKA po KLATCE                        19     19          19
# KOLOSEUM                                 6      6           6
# KOstyra SE                               2      2           2
# KSW International                        5      5           5
# Kanał Sportowy                          14     14          14
# MMA INFO                                 9      9           9
# MMA Rocks                                2      2           2
# MMAPLtv                                  1      1           1
# MMAPUNCH                                 1      1           1
# MY TO SUKCES                             2      2           2
# Mariusz Paszczyk                         5      5           5
# Mateusz Kaniowski                        2      2           2
# Next MMA                                 1      1           1
# PIT BULL WEST COAST                      1      1           1
# PapiTV                                   1      1           1
# Paweł Maciak                             2      2           2
# Szalony Podcast                          1      1           1
# TVP Sport                                1      1           1
# TVreklama                                2      2           2
# Triangle TV                              1      1           1
# Tv F-O-T-O  wydarzenia i wywiady         1      1           1
# World Of MMA                             1      1           1
# afanik                                   2      2           2
# ebe ebe                                  1      1           1
# forBET                                   1      1           1
# illegal TV                               3      3           3
# myMMApl                                  4      4           4
# ОКТА ММА                                 1      1           1
#
#                                   channel_subscribers
# channel
# 6PAK                                                1
# BOXDEL                                              1
# FANSPORTU TV                                       10
# Fair Play Thinker podcast                           1
# FightsportPL                                        3
# Fortuna - Zakłady bukmacherskie                     2
# InTheCagePL                                        15
# Interia Sport                                       1
# KANAŁ O WALKACH                                     1
# KLATKA po KLATCE                                   19
# KOLOSEUM                                            6
# KOstyra SE                                          2
# KSW International                                   5
# Kanał Sportowy                                     14
# MMA INFO                                            9
# MMA Rocks                                           2
# MMAPLtv                                             1
# MMAPUNCH                                            1
# MY TO SUKCES                                        2
# Mariusz Paszczyk                                    5
# Mateusz Kaniowski                                   2
# Next MMA                                            1
# PIT BULL WEST COAST                                 1
# PapiTV                                              1
# Paweł Maciak                                        2
# Szalony Podcast                                     1
# TVP Sport                                           1
# TVreklama                                           2
# Triangle TV                                         1
# Tv F-O-T-O  wydarzenia i wywiady                    1
# World Of MMA                                        1
# afanik                                              2
# ebe ebe                                             1
# forBET                                              1
# illegal TV                                          3
# myMMApl                                             4
# ОКТА ММА                                            1

# %%
tokenizer = RegexpTokenizer(r'\w+')

clean_df["tokens"] = clean_df["title"].apply(tokenizer.tokenize)
clean_df.head()
# Out:
# /var/folders/mp/mpgc14lx6b9f41xmhqs4mxc80000gn/T/ipykernel_15007/49885964.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df["tokens"] = clean_df["title"].apply(tokenizer.tokenize)
#        video_id                                              title view_count  \
# 1   vDICqILiGQQ  historyczna sportowa walka na fame mma?(ksw,uf...       4371
# 4   zbvfrGob5mY  kizo ft. kabe, reto, gruby mielzky, borixon - ...    6935619
# 8   AMrL_AcVf04  oliwier jarzecki | 2 wygrane na jednej gali | ...        236
# 10  e1-u_eF0UBA  ksw free fight: mamed khalidov vs. mariusz pud...     144250
# 15  HDQDYa5jnWE  ogromne problemy ksw! co dalej z galami? (viap...      10558
#
#                              channel channel_subscribers  \
# 1                           MMA INFO               11600
# 4                       MY TO SUKCES             1000000
# 8   Tv F-O-T-O  wydarzenia i wywiady                2250
# 10                 KSW International               16700
# 15                          MMA INFO               11600
#
#                                                tokens
# 1   [historyczna, sportowa, walka, na, fame, mma, ...
# 4   [kizo, ft, kabe, reto, gruby, mielzky, borixon...
# 8   [oliwier, jarzecki, 2, wygrane, na, jednej, ga...
# 10  [ksw, free, fight, mamed, khalidov, vs, marius...
# 15  [ogromne, problemy, ksw, co, dalej, z, galami,...

# %%
all_words = [word for sublist in clean_df["tokens"] for word in sublist]

# Convert array to Pandas Series
word_series = pd.Series(all_words)

# Filter out words that have at least 3 characters
filtered_words = word_series[word_series.apply(lambda x: len(x) > 3)]

# Count the occurrences of each word
word_counts = filtered_words.value_counts()

#I need to create a list of words that can disturb my data mining. These are parts of speech other than nouns and words with a meaning broader than mma
list_of_disturbing_words = ['quot', 'przed', 'gali', 'fight', 'shorts', 'podsumowanie', 'mateusz', 'free', 'walce', 'słowa', '2023', 'dalej']

# Choose the 10 most common words
hot_words = word_counts.head(30).index.tolist()

for word in hot_words:
    if word in list_of_disturbing_words:

        hot_words.remove(word)

top_10_words = hot_words[0:10]

# %%
print(top_10_words)
# Out:
# ['colosseum', 'szpilka', 'pudzianowski', 'khalidov', 'fame', 'mamed', 'pudzian', 'klatka', 'klatce', 'parnasse']

# %% [markdown]
# now I'll read more data from API

# %%
TOTAL_VIDEOS = 1000

videos = get_videos_with_keyword(top_10_words, TOTAL_VIDEOS, MAX_RESULTS_PER_PAGE, DELAY_BETWEEN_REQUESTS)

video_data = []
for video in videos:
    video_id = video['id']['videoId']
    title = video['snippet']['title']
    publish_time = video['snippet']['publishTime']
    statistics = get_video_statistics(video_id)
    view_count = statistics.get('viewCount', 0)
    channel_id = video['snippet']['channelId']
    channel = video['snippet']['channelTitle']
    channel_statistics = get_channel_statistics(channel_id)
    channel_subscribers = channel_statistics.get('subscriberCount', 0)
    video_info = {
        'video_id': video_id,
        'title': title,
        'view_count': view_count,
        'channel': channel,
        'channel_subscribers': channel_subscribers,
        'publish_time': publish_time,
    }
    video_data.append(video_info)

# Confersion of dicts to DataFrame
df = pd.DataFrame(video_data)

# %%
videos[0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'tjulP9HNDhumXRAEAuaHbSCY4cM',
#  'id': {'kind': 'youtube#video', 'videoId': 'FdswhegK0mU'},
#  'snippet': {'publishedAt': '2023-05-31T14:00:09Z',
#   'channelId': 'UCRqvJVpMT9dzhX5UzRXPQbg',
#   'title': 'KSW Free Fight: Salahdine Parnasse vs. Sebastian Rajewski',
#   'description': "France's Salahdine Parnasse captured his second KSW title with this win over Sebastian Rajewski from KSW 76. He now faces ...",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FdswhegK0mU/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/FdswhegK0mU/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/FdswhegK0mU/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'KSW International',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2023-05-31T14:00:09Z'}}

# %%
df.head()
# Out:
#       video_id                                              title view_count  \
# 0  FdswhegK0mU  KSW Free Fight: Salahdine Parnasse vs. Sebasti...     148591
# 1  IS6DTtPdb9I    Salahdine Parnasse - Wirtuoz i showman | KSW 68      37359
# 2  X_PW5kCXfzk  KSW Free Fight: Salahdine Parnasse vs. Daniel ...     231898
# 3  KzaM4AOf-nU                      TAKTYKI NA PARNASSE | TRENING      11911
# 4  2pKUU93zyvQ  Salahdine Parnasse, Le Jeune Prodige du MMA - ...     182965
#
#              channel channel_subscribers publish_time
# 0  KSW International               16700          NaN
# 1                KSW              506000          NaN
# 2  KSW International               16700          NaN
# 3     Robert Ruchała                4140          NaN
# 4               ZACK              663000          NaN

# %%
# Export to CSV
df.to_csv('youtube_data.csv', index=False)

# %% [markdown]
# Here I finished data aggregation. Futher work will be done in seperate file.
